# %% [markdown]
# ## .py側との連携

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !ls 

from ml_pipeline import MoisturePipeline
# Out:
# Untitled.ipynb	 __pycache__	       lgb-1.ipynb     mlflow-1.ipynb
# Untitled1.ipynb  data_count.ipynb      lgb-2.ipynb     mlflow-gingo-2.ipynb
# Untitled2.ipynb  data_histgrams.ipynb  ml_pipeline.py  mlflow-gingo.ipynb

# %%
import polars as pl

train_data_pl = pl.read_csv(r"../data/train.csv",encoding="shift_jis")

test_data_pl =  pl.read_csv(r"../data/test.csv",encoding="shift_jis")

# %%
# 含水率をlogにして計算しやすくする

train_data_pl_new = train_data_pl.with_columns(
    pl.col("含水率").log().alias("含水率_log")
)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 9
#       3 train_data_pl_new = train_data_pl.with_columns(
#       4     pl.col("含水率").log().alias("含水率_log")
#       5 )
#       7 # 含水率をlogにして計算しやすくする
# ----> 9 test_data_pl_new = test_data_pl.with_columns(
#      10     pl.col("含水率").log().alias("含水率_log")
#      11 )
#
# File /usr/local/lib/python3.11/site-packages/polars/dataframe/frame.py:10507, in DataFrame.with_columns(self, *exprs, **named_exprs)
#   10380 """
#   10381 Add columns to this DataFrame.
#   10382
#    (...)  10500 └─────┴──────┴───────┴──────┴───────┘
#   10501 """
#   10502 from polars.lazyframe.opt_flags import QueryOptFlags
#   10504 return (
#   10505     self.lazy()
#   10506     .with_columns(*exprs, **named_exprs)
# > 10507     .collect(optimizations=QueryOptFlags._eager())
#   10508 )
#
# File /usr/local/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:326, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     323         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     325 kwargs["optimizations"] = optflags
# --> 326 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/frame.py:2464, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2462 # Only for testing purposes
#    2463 callback = _kwargs.get("post_opt_callback", callback)
# -> 2464 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "含水率"; valid columns: ["sample number", "species number", "樹種", "9993.76781", "9989.9107", "9986.05359", "9982.19648", "9978.33937", "9974.48227", "9970.62516", "9966.76805", "9962.91094", "9959.05383", "9955.19672", "9951.33962", "9947.48251", "9943.6254", "9939.76829", "9935.91118", "9932.05407", "9928.19697", "9924.33986", "9920.48275", "9916.62564", "9912.76853", "9908.91142", "9905.05432", "9901.19721", "9897.3401", "9893.48299", "9889.62588", "9885.76877", "9881.91166", "9878.05456", "9874.19745", "9870.34034", "9866.48323", "9862.62612", "9858.76901", "9854.91191", "9851.0548", "9847.19769", "9843.34058", "9839.48347", "9835.62636", "9831.76926", "9827.91215", "9824.05504", "9820.19793", "9816.34082", "9812.48371", "9808.62661", "9804.7695", "9800.91239", "9797.05528", "9793.19817", "9789.34106", "9785.48396", "9781.62685", "9777.76974", "9773.91263", "9770.05552", "9766
041.06204", "9037.20493", "9033.34782", "9029.49071", "9025.6336", "9021.7765", "9017.91939", "9014.06228", "9010.20517", "9006.34806", "9002.49095", "8998.63385", "8994.77674", "8990.91963", "8987.06252", "8983.20541", "8979.3483", "8975.4912", "8971.63409", "8967.77698", "8963.91987", "8960.06276", "8956.20565", "8952.34855", "8948.49144", "8944.63433", "8940.77722", "8936.92011", "8933.063", "8929.2059", "8925.34879", "8921.49168", "8917.63457", "8913. ...

# %%
# 含水率をlogにして計算しやすくする

test_data_pl_new = test_data_pl.with_columns(
    pl.col("含水率").log().alias("含水率_log")
)

# %%
import sys
#sys.path.append("../src")  # 必要なら

# ===== ③ 実行 =====
pipe = MoisturePipeline(species="gingo")

# %%
pipe.run_mlflow(train_data_pl_new)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 396780
# [LightGBM] [Info] Number of data points in the train set: 1057, number of used features: 1556
# [LightGBM] [Info] Start training from score 3.408297
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# 2026/03/29 23:01:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# 2026/03/29 23:01:15 WARNING mlflow.lightgbm: Saving the models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# [gingo] RMSE: 0.014783202254898568
# 🏃 View run tasteful-mouse-304 at: http://mlflow:5000/#/experiments/2/runs/1e1bf88fe9d44cfbac443a1b9866f301
# 🧪 View experiment at: http://mlflow:5000/#/experiments/2

# %%
pred = pipe.predict(test_data_pl)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pred = pipe.predict(test_data_pl)
#
# File /work/ml_pipeline.py:64, in MoisturePipeline.predict(self, test_df)
#      60 def predict(self, test_df: pl.DataFrame):
#      61     """
#      62     testデータのブロック
#      63     """
# ---> 64     X = self.preprocess(test_df, is_train=False)
#      65     return self.model.predict(X)
#
# File /work/ml_pipeline.py:34, in MoisturePipeline.preprocess(self, df, is_train)
#      30 def preprocess(self, df: pl.DataFrame, is_train=True):
#      31     """
#      32     前処理ブロック
#      33     """
# ---> 34     X = df.drop(self.drop_cols).to_numpy()
#      36     if is_train:
#      37         y = df["含水率_log"].to_numpy()
#
# File /usr/local/lib/python3.11/site-packages/polars/dataframe/frame.py:8880, in DataFrame.drop(self, strict, *columns)
#    8797 """
#    8798 Remove columns from the dataframe.
#    8799
#    (...)   8873 └─────┘
#    8874 """
#    8875 from polars.lazyframe.opt_flags import QueryOptFlags
#    8877 return (
#    8878     self.lazy()
#    8879     .drop(*columns, strict=strict)
# -> 8880     .collect(optimizations=QueryOptFlags._eager())
#    8881 )
#
# File /usr/local/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:326, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     323         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     325 kwargs["optimizations"] = optflags
# --> 326 return function(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/polars/lazyframe/frame.py:2464, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2462 # Only for testing purposes
#    2463 callback = _kwargs.get("post_opt_callback", callback)
# -> 2464 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: "含水率" not found
